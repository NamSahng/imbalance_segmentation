# %%
import os
import re
import json
import sqlite3

import pandas as pd
import numpy as np
from glob import glob

import warnings
warnings.filterwarnings('ignore')


pd.set_option('display.max_columns', 50)

# %%
os.chdir('../../')

# %%
result_paths = glob('./output/*/*/*.csv')

# %%
results = []
for p in result_paths:
    df = pd.read_csv(p, index_col=0)
    result = dict(df.apply(lambda x: np.nanmean(x)))
    configs = p.split('/')[2]
    is_imbalance, split_strategy, resampling_strategy, \
    do_copypaste, paste_by = configs.replace('skf_prop','skfprop').split('_')
    mIoU = np.nanmean(list(result.values()))
    random_state= p.split('/')[3]
    result.update(
        configs = configs,
        is_imbalance = is_imbalance,
        split_strategy = split_strategy,
        resampling_strategy = resampling_strategy,
        do_copypaste = do_copypaste,
        paste_by = paste_by,
        random_state = random_state,
        test_mIoU = mIoU
    )
    results.append(result)

# %%
result_df = pd.DataFrame(results)
result_df["is_imbalance"] = result_df.is_imbalance == "TRUE"
result_df["do_copypaste"] = result_df.do_copypaste == "TRUE"

label_cols = ['aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus', 'car', 'cat',
'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike', 'person',
'pottedplant', 'sheep', 'sofa', 'train', 'tvmonitor', 'background']

search_spaces = ['is_imbalance', 'split_strategy', 'resampling_strategy', 'do_copypaste', 'paste_by']

non_label_cols = [col for col in result_df.columns if col not in label_cols]
result_df = result_df[non_label_cols + label_cols]

# %%
pd.DataFrame(result_df.groupby(search_spaces)[['test_mIoU']+label_cols].mean()).reset_index()
# Out:
#    is_imbalance split_strategy resampling_strategy  do_copypaste     paste_by  \
# 0         False           mskf                  x2         False         none
# 1         False         random                  x2         False         none
# 2          True           mskf                 cnt         False         none
# 3          True           mskf                 cnt          True          cnt
# 4          True           mskf                 cnt          True  performance
# 5          True         random                  x2         False         none
# 6          True         random                  x2          True          cnt
# 7          True         random                  x2          True  performance
# 8          True        skfprop             cluster         False         none
#
#    test_mIoU  aeroplane   bicycle      bird      boat    bottle       bus  \
# 0   0.555109   0.654149  0.282342  0.646530  0.521285  0.360246  0.703331
# 1   0.555764   0.658487  0.285800  0.641149  0.521367  0.362211  0.719109
# 2   0.518855   0.601401  0.238893  0.534862  0.508663  0.252073  0.710929
# 3   0.528834   0.619071  0.278994  0.552960  0.492692  0.286117  0.711082
# 4   0.529656   0.605054  0.279017  0.510021  0.526471  0.304825  0.720491
# 5   0.518869   0.545740  0.212530  0.525782  0.511430  0.274431  0.710647
# 6   0.531912   0.601056  0.256784  0.554669  0.502715  0.333971  0.724619
# 7   0.531783   0.548969  0.253544  0.533152  0.529475  0.326867  0.726580
# 8   0.510055   0.528647  0.196652  0.478498  0.498604  0.260868  0.708872
#
#         car       cat     chair       cow  diningtable       dog     horse  \
# 0  0.476271  0.751790  0.180076  0.714085     0.461101  0.683473  0.637727
# 1  0.469919  0.759668  0.180420  0.717171     0.459377  0.689982  0.627426
# 2  0.449996  0.662532  0.058378  0.694770     0.396763  0.692225  0.629112
# 3  0.458033  0.682652  0.093502  0.664231     0.412092  0.685738  0.627890
# 4  0.462681  0.654150  0.100524  0.692089     0.366220  0.689769  0.608551
# 5  0.471677  0.663291  0.049116  0.704459     0.386190  0.704280  0.633196
# 6  0.467937  0.673928  0.104954  0.679059     0.394572  0.681950  0.625286
# 7  0.476222  0.653660  0.097984  0.676347     0.389443  0.697141  0.647493
# 8  0.435136  0.656348  0.050411  0.687986     0.389929  0.698500  0.637502
#
#    motorbike    person  pottedplant     sheep      sofa     train  tvmonitor  \
# 0   0.649251  0.566585     0.218413  0.632647  0.444444  0.717082   0.476606
# 1   0.644140  0.566040     0.229399  0.616648  0.426433  0.734207   0.481672
# 2   0.643607  0.541202     0.234817  0.592788  0.412543  0.715874   0.453829
# 3   0.622289  0.543527     0.269585  0.619472  0.435119  0.711396   0.470887
# 4   0.631195  0.547929     0.294601  0.614052  0.445312  0.714417   0.486378
# 5   0.650438  0.553209     0.245455  0.602148  0.402915  0.711910   0.467336
# 6   0.630751  0.554687     0.269211  0.619132  0.434056  0.725580   0.464499
# 7   0.645632  0.556976     0.290034  0.617863  0.430945  0.728808   0.471367
# 8   0.645161  0.546821     0.238495  0.601619  0.416707  0.709685   0.455140
#
#    background
# 0    0.879851
# 1    0.880416
# 2    0.870707
# 3    0.868178
# 4    0.869037
# 5    0.870059
# 6    0.870729
# 7    0.868934
# 8    0.869583

# %%
imbalanced_labels =  "bird, cat, aeroplane, bicycle, bottle, chair".split(', ')

balaced_labels = list(set(label_cols) - set(imbalanced_labels))

# %%
pd.DataFrame(result_df.groupby(search_spaces)[['test_mIoU']+imbalanced_labels].mean()).reset_index()
# Out:
#    is_imbalance split_strategy resampling_strategy  do_copypaste     paste_by  \
# 0         False           mskf                  x2         False         none
# 1         False         random                  x2         False         none
# 2          True           mskf                 cnt         False         none
# 3          True           mskf                 cnt          True          cnt
# 4          True           mskf                 cnt          True  performance
# 5          True         random                  x2         False         none
# 6          True         random                  x2          True          cnt
# 7          True         random                  x2          True  performance
# 8          True        skfprop             cluster         False         none
#
#    test_mIoU      bird       cat  aeroplane   bicycle    bottle     chair
# 0   0.555109  0.646530  0.751790   0.654149  0.282342  0.360246  0.180076
# 1   0.555764  0.641149  0.759668   0.658487  0.285800  0.362211  0.180420
# 2   0.518855  0.534862  0.662532   0.601401  0.238893  0.252073  0.058378
# 3   0.528834  0.552960  0.682652   0.619071  0.278994  0.286117  0.093502
# 4   0.529656  0.510021  0.654150   0.605054  0.279017  0.304825  0.100524
# 5   0.518869  0.525782  0.663291   0.545740  0.212530  0.274431  0.049116
# 6   0.531912  0.554669  0.673928   0.601056  0.256784  0.333971  0.104954
# 7   0.531783  0.533152  0.653660   0.548969  0.253544  0.326867  0.097984
# 8   0.510055  0.478498  0.656348   0.528647  0.196652  0.260868  0.050411

# %%
pd.DataFrame(result_df.groupby(search_spaces)[['test_mIoU']+balaced_labels].mean()).reset_index()
# Out:
#    is_imbalance split_strategy resampling_strategy  do_copypaste     paste_by  \
# 0         False           mskf                  x2         False         none
# 1         False         random                  x2         False         none
# 2          True           mskf                 cnt         False         none
# 3          True           mskf                 cnt          True          cnt
# 4          True           mskf                 cnt          True  performance
# 5          True         random                  x2         False         none
# 6          True         random                  x2          True          cnt
# 7          True         random                  x2          True  performance
# 8          True        skfprop             cluster         False         none
#
#    test_mIoU  tvmonitor  motorbike    person      boat      sofa     horse  \
# 0   0.555109   0.476606   0.649251  0.566585  0.521285  0.444444  0.637727
# 1   0.555764   0.481672   0.644140  0.566040  0.521367  0.426433  0.627426
# 2   0.518855   0.453829   0.643607  0.541202  0.508663  0.412543  0.629112
# 3   0.528834   0.470887   0.622289  0.543527  0.492692  0.435119  0.627890
# 4   0.529656   0.486378   0.631195  0.547929  0.526471  0.445312  0.608551
# 5   0.518869   0.467336   0.650438  0.553209  0.511430  0.402915  0.633196
# 6   0.531912   0.464499   0.630751  0.554687  0.502715  0.434056  0.625286
# 7   0.531783   0.471367   0.645632  0.556976  0.529475  0.430945  0.647493
# 8   0.510055   0.455140   0.645161  0.546821  0.498604  0.416707  0.637502
#
#       train       bus       car  pottedplant  diningtable       dog       cow  \
# 0  0.717082  0.703331  0.476271     0.218413     0.461101  0.683473  0.714085
# 1  0.734207  0.719109  0.469919     0.229399     0.459377  0.689982  0.717171
# 2  0.715874  0.710929  0.449996     0.234817     0.396763  0.692225  0.694770
# 3  0.711396  0.711082  0.458033     0.269585     0.412092  0.685738  0.664231
# 4  0.714417  0.720491  0.462681     0.294601     0.366220  0.689769  0.692089
# 5  0.711910  0.710647  0.471677     0.245455     0.386190  0.704280  0.704459
# 6  0.725580  0.724619  0.467937     0.269211     0.394572  0.681950  0.679059
# 7  0.728808  0.726580  0.476222     0.290034     0.389443  0.697141  0.676347
# 8  0.709685  0.708872  0.435136     0.238495     0.389929  0.698500  0.687986
#
#       sheep  background
# 0  0.632647    0.879851
# 1  0.616648    0.880416
# 2  0.592788    0.870707
# 3  0.619472    0.868178
# 4  0.614052    0.869037
# 5  0.602148    0.870059
# 6  0.619132    0.870729
# 7  0.617863    0.868934
# 8  0.601619    0.869583

# %%
train_logs = open('/home/nys/nni-experiments/08bsa6re/log/nnimanager.log')
train_logs = train_logs.read().splitlines()
start_times = [log for log in train_logs if "WAITING to RUNNING" in log]
end_times = [log for log in train_logs if "RUNNING to SUCCEEDED" in log]
configs = [log for log in train_logs if "dispatcher: TR" in log]

# %%
assert len(start_times) == len(end_times)
assert len(start_times) == len(configs)

# %%
box_bracket = r"\[.*?\]"
param_str = "\"parameters\": "
curly_bracket = param_str + "\{.*?\}"
job_name = "Trial job \w+"

config_times = [re.findall(box_bracket, log)[0] for log in configs]
config_args = [json.loads(re.sub(param_str, "",
                          re.findall(curly_bracket, log)[0])) for log in configs]

starts = [re.findall(box_bracket, log)[0] for log in start_times]
ends = [re.findall(box_bracket, log)[0] for log in end_times]
job_names = [re.sub("Trial job ","",re.findall(job_name, log)[0]) for log in start_times]

# %%
log_df = pd.DataFrame(config_args)

# %%
log_df['job_name'] = job_names
log_df['config_time'] = config_times
log_df['start_time'] = starts
log_df['end_time'] = ends
log_df['config_time'] = config_times

time_cols = [col for col in log_df.columns if 'time' in col]

for col in (time_cols):
    log_df[col] = log_df[col].apply(lambda x: x.replace("[", "").replace("]",""))
    log_df[col] = pd.to_datetime(log_df[col])

log_df['train_time'] = log_df['end_time'] - log_df['start_time']

# %%
con = sqlite3.connect('/home/nys/nni-experiments/08bsa6re/db/nni.sqlite')
cur = con.cursor()
cur.execute("SELECT name FROM sqlite_master WHERE type='table';")

print(cur.fetchall())

exp_profile = pd.read_sql_query("SELECT * FROM ExperimentProfile;",con)
metric_data = pd.read_sql_query("SELECT * FROM MetricData;",con)
trial_event = pd.read_sql_query("SELECT * FROM TrialJobEvent;",con)

display(exp_profile.head(3))
display(metric_data.head(3))
display(trial_event.head(3))
# Out:
# [('TrialJobEvent',), ('MetricData',), ('ExperimentProfile',)]
#                                               params        id  execDuration  \
# 0  {"searchSpaceFile":"/home/nys/Desktop/study_20...  08bsa6re             0
# 1  {"searchSpaceFile":"/home/nys/Desktop/study_20...  08bsa6re             0
# 2  {"searchSpaceFile":"/home/nys/Desktop/study_20...  08bsa6re             5
#
#        startTime endTime                              logDir  nextSequenceId  \
# 0  1655635275953    None  /home/nys/nni-experiments/08bsa6re               0
# 1  1655635275953    None  /home/nys/nni-experiments/08bsa6re               0
# 2  1655635275953    None  /home/nys/nni-experiments/08bsa6re               1
#
#    revision
# 0         1
# 1         2
# 2         3
#        timestamp trialJobId parameterId        type  sequence  \
# 0  1655635577605      jYQpo           0  PERIODICAL         0
# 1  1655635863536      jYQpo           0  PERIODICAL         1
# 2  1655636149676      jYQpo           0  PERIODICAL         2
#
#                    data
# 0  "0.5529635354201905"
# 1  "0.5696392811953479"
# 2  "0.5905676542029943"
#        timestamp trialJobId      event  \
# 0  1655635281050      jYQpo    WAITING
# 1  1655635286073      jYQpo    RUNNING
# 2  1655657098615      jYQpo  SUCCEEDED
#
#                                                 data  \
# 0  {"parameter_id": 0, "parameter_source": "algor...
# 1                                               None
# 2                                               None
#
#                                              logPath  sequenceId message
# 0  file://localhost:/home/nys/nni-experiments/08b...           0    None
# 1  file://localhost:/home/nys/nni-experiments/08b...           0    None
# 2  file://localhost:/home/nys/nni-experiments/08b...           0    None

# %%
metric_data["epoch_val_mIoU"] = metric_data.data.str.replace("\"", "").astype(float)
max_epoch = metric_data.groupby('trialJobId')['sequence', 'epoch_val_mIoU'].max()
max_epoch = max_epoch.reset_index()
max_epoch.columns = ["job_name", 'train_epoch', "epoch_val_mIoU"]

# %%
log_df = pd.merge(log_df, max_epoch, on="job_name", how="left")

# %%
log_df['avg_epoch_time'] = log_df.train_time / log_df.train_epoch

log_df['configs'] = log_df.configs.str.replace(" ","_")
log_df = log_df.rename(columns={"split_rs": "random_state"})
log_df['random_state']= log_df.random_state.astype(str)
result_df['random_state']= result_df.random_state.astype(str)

display(log_df.head(3))
# Out:
#   random_state  split_fnum                     configs job_name  \
# 0            1           0  FALSE_random_x2_FALSE_none    jYQpo
# 1            1           0    FALSE_mskf_x2_FALSE_none    m7ltG
# 2            1           0   TRUE_random_x2_FALSE_none    sKpWx
#
#           config_time          start_time            end_time      train_time  \
# 0 2022-06-19 19:41:16 2022-06-19 19:41:26 2022-06-20 01:45:00 0 days 06:03:34
# 1 2022-06-20 01:45:00 2022-06-20 01:45:10 2022-06-20 08:07:31 0 days 06:22:21
# 2 2022-06-20 08:07:31 2022-06-20 08:07:41 2022-06-20 12:26:32 0 days 04:18:51
#
#    train_epoch  epoch_val_mIoU            avg_epoch_time
# 0           76        0.697371 0 days 00:04:47.026315789
# 1           80        0.709051    0 days 00:04:46.762500
# 2           79        0.708310 0 days 00:03:16.594936708

# %%
result_df = pd.merge(log_df, result_df, on= ["configs", "random_state"], how="left")

# %%
result_df.head()
# Out:
#   random_state  split_fnum                           configs job_name  \
# 0            1           0        FALSE_random_x2_FALSE_none    jYQpo
# 1            1           0          FALSE_mskf_x2_FALSE_none    m7ltG
# 2            1           0         TRUE_random_x2_FALSE_none    sKpWx
# 3            1           0          TRUE_mskf_cnt_FALSE_none    HYdBk
# 4            1           0  TRUE_skf_prop_cluster_FALSE_none    ZlfNW
#
#           config_time          start_time            end_time      train_time  \
# 0 2022-06-19 19:41:16 2022-06-19 19:41:26 2022-06-20 01:45:00 0 days 06:03:34
# 1 2022-06-20 01:45:00 2022-06-20 01:45:10 2022-06-20 08:07:31 0 days 06:22:21
# 2 2022-06-20 08:07:31 2022-06-20 08:07:41 2022-06-20 12:26:32 0 days 04:18:51
# 3 2022-06-20 12:26:33 2022-06-20 12:26:43 2022-06-20 17:02:05 0 days 04:35:22
# 4 2022-06-20 17:02:05 2022-06-20 17:02:15 2022-06-20 21:58:28 0 days 04:56:13
#
#    train_epoch  epoch_val_mIoU            avg_epoch_time  is_imbalance  \
# 0           76        0.697371 0 days 00:04:47.026315789         False
# 1           80        0.709051    0 days 00:04:46.762500         False
# 2           79        0.708310 0 days 00:03:16.594936708          True
# 3           84        0.725555 0 days 00:03:16.690476190          True
# 4           92        0.735685 0 days 00:03:13.184782608          True
#
#   split_strategy resampling_strategy  do_copypaste paste_by  test_mIoU  \
# 0         random                  x2         False     none   0.557497
# 1           mskf                  x2         False     none   0.553489
# 2         random                  x2         False     none   0.523494
# 3           mskf                 cnt         False     none   0.523744
# 4        skfprop             cluster         False     none   0.512570
#
#    aeroplane   bicycle      bird      boat    bottle       bus       car  \
# 0   0.652341  0.290290  0.635696  0.520608  0.347514  0.735243  0.436864
# 1   0.649023  0.276470  0.653448  0.519311  0.347857  0.712158  0.492618
# 2   0.569173  0.238537  0.541929  0.508524  0.264707  0.725048  0.477476
# 3   0.597629  0.234189  0.526076  0.501576  0.285600  0.695156  0.446776
# 4   0.552205  0.171125  0.488038  0.503097  0.284481  0.706901  0.416296
#
#         cat     chair       cow  diningtable       dog     horse  motorbike  \
# 0  0.759840  0.196924  0.736267     0.466755  0.696865  0.607881   0.662733
# 1  0.755708  0.168507  0.712359     0.452551  0.671878  0.631143   0.655712
# 2  0.671550  0.042267  0.710797     0.383865  0.711472  0.625931   0.658192
# 3  0.692041  0.053670  0.707520     0.410013  0.695629  0.633472   0.639259
# 4  0.701284  0.044661  0.734790     0.328529  0.695073  0.635188   0.637767
#
#      person  pottedplant     sheep      sofa     train  tvmonitor  background
# 0  0.564343     0.220733  0.632440  0.450738  0.727686   0.486342    0.879340
# 1  0.569532     0.203210  0.658307  0.427302  0.728016   0.458932    0.879225
# 2  0.552872     0.266131  0.592191  0.400734  0.707999   0.471167    0.872811
# 3  0.544872     0.252745  0.615439  0.418436  0.731712   0.444342    0.872465
# 4  0.555330     0.231980  0.601085  0.413620  0.712856   0.480403    0.869257

# %%
train_df = pd.read_csv('./data/train_df.csv', index_col=0)

# %%
pixel_cols = [i for i in train_df.columns if 'sum' in i]
cnt_cols = [i for i in train_df.columns if 'cnt' in i]
prop_cols = [i for i in train_df.columns if 'prop' in i]

# %%
split_strategies = ["random", "mskf", "skf_prop"]

# %%
data_stats = []

for s_st in split_strategies:
    for rs in range(1,6):
        cur_split = f"{s_st}_rstate{rs}_fold0"
        
        condition = ((train_df[cur_split] == 'train')&(train_df["use_image"]))
        
        num_train = len(train_df[condition])
        
        is_imbalance = True

        train_info = pd.Series(dict(cur_data=cur_split, num_train=num_train, is_imbalance=is_imbalance,
                                    split_strategy= s_st, random_state = rs))

        freq_sum = train_df[condition][cnt_cols].sum()
        
        proportion_mean = train_df[condition][prop_cols].mean()
        nz_proportion_mean = train_df[condition][prop_cols].replace(0,np.NaN).mean(numeric_only=True)
        
        pixel_mean = train_df[condition][pixel_cols].mean()
        nz_pixel_mean = train_df[condition][pixel_cols].replace(0,np.NaN).mean(numeric_only=True)
        
        nz_proportion_mean = nz_proportion_mean.rename(lambda x: x.replace('prop', 'nz_prop'))
        pixel_mean = pixel_mean.rename(lambda x: x.replace('sum', 'pix'))
        nz_pixel_mean = nz_pixel_mean.rename(lambda x: x.replace('sum', 'nz_pix'))

        cur_stats = pd.concat([train_info, freq_sum, pixel_mean, proportion_mean, nz_pixel_mean, nz_proportion_mean])
        data_stats.append(cur_stats)
        
        
split_strategies = ["random", "mskf"]
for s_st in split_strategies:
    for rs in range(1,6):
        cur_split = f"{s_st}_rstate{rs}_fold0"
        condition = ((train_df[cur_split] == 'train'))

        num_train = len(train_df[condition])
        
        is_imbalance = False
        train_info = pd.Series(dict(cur_data=cur_split, num_train=num_train, is_imbalance=is_imbalance,
                                    split_strategy= s_st, random_state = rs))

        freq_sum = train_df[condition][cnt_cols].sum()

        proportion_mean = train_df[condition][prop_cols].mean()
        nz_proportion_mean = train_df[condition][prop_cols].replace(0,np.NaN).mean(numeric_only=True)

        pixel_mean = train_df[condition][pixel_cols].mean()
        nz_pixel_mean = train_df[condition][pixel_cols].replace(0,np.NaN).mean(numeric_only=True)

        nz_proportion_mean = nz_proportion_mean.rename(lambda x: x.replace('prop', 'nz_prop'))
        pixel_mean = pixel_mean.rename(lambda x: x.replace('sum', 'pix'))
        nz_pixel_mean = nz_pixel_mean.rename(lambda x: x.replace('sum', 'nz_pix'))

        cur_stats = pd.concat([train_info, freq_sum, pixel_mean, proportion_mean, nz_pixel_mean, nz_proportion_mean])
        data_stats.append(cur_stats)

data_stats_df = pd.DataFrame(data_stats)

# %%
data_stats_df['random_state'] = data_stats_df.random_state.astype(str)

# %%
result_df = pd.merge(result_df, data_stats_df, on=['is_imbalance', 'split_strategy', 'random_state'], how='left')

# %%
result_df.tail(3)
# Out:
#    random_state  split_fnum                          configs job_name  \
# 42            5           0  TRUE_random_x2_TRUE_performance    mKpwE
# 43            5           0           TRUE_mskf_cnt_TRUE_cnt    L9O3N
# 44            5           0   TRUE_mskf_cnt_TRUE_performance    eANW9
#
#            config_time          start_time            end_time  \
# 42 2022-06-28 12:20:13 2022-06-28 12:20:23 2022-06-28 17:26:38
# 43 2022-06-28 17:26:38 2022-06-28 17:26:48 2022-06-28 22:05:02
# 44 2022-06-28 22:05:02 2022-06-28 22:05:12 2022-06-29 02:47:21
#
#         train_time  train_epoch  epoch_val_mIoU            avg_epoch_time  \
# 42 0 days 05:06:15           85        0.702703 0 days 00:03:36.176470588
# 43 0 days 04:38:14           77        0.720606 0 days 00:03:36.805194805
# 44 0 days 04:42:09           78        0.716841 0 days 00:03:37.038461538
#
#     is_imbalance split_strategy resampling_strategy  do_copypaste  \
# 42          True         random                  x2          True
# 43          True           mskf                 cnt          True
# 44          True           mskf                 cnt          True
#
#        paste_by  test_mIoU  aeroplane   bicycle      bird      boat    bottle  \
# 42  performance   0.528944   0.537103  0.262124  0.524057  0.538465  0.342418
# 43          cnt   0.533357   0.620599  0.284601  0.571450  0.498367  0.261101
# 44  performance   0.534125   0.640592  0.278050  0.528296  0.542828  0.291260
#
#          bus       car       cat  ...  tvmonitor_nz_pix  background_nz_pix  \
# 42  0.742397  0.475790  0.641379  ...       34047.97619      125786.413619
# 43  0.713364  0.448173  0.694778  ...       26282.97561      125082.895597
# 44  0.706637  0.453839  0.650199  ...       26282.97561      125082.895597
#
#     border_nz_pix  aeroplane_nz_prop  bicycle_nz_prop  bird_nz_prop  \
# 42    8591.760404           0.127145         0.116980      0.120797
# 43    8696.346734           0.115723         0.097352      0.127703
# 44    8696.346734           0.115723         0.097352      0.127703
#
#     boat_nz_prop  bottle_nz_prop  bus_nz_prop  car_nz_prop  cat_nz_prop  \
# 42      0.112703        0.142537     0.302753     0.170940     0.282111
# 43      0.114715        0.107090     0.316531     0.157806     0.258600
# 44      0.114715        0.107090     0.316531     0.157806     0.258600
#
#     chair_nz_prop  cow_nz_prop diningtable_nz_prop  dog_nz_prop  \
# 42       0.141748     0.200593            0.219353     0.201514
# 43       0.134952     0.172318            0.243299     0.214182
# 44       0.134952     0.172318            0.243299     0.214182
#
#     horse_nz_prop  motorbike_nz_prop  person_nz_prop  pottedplant_nz_prop  \
# 42       0.204122           0.184887        0.141688             0.132353
# 43       0.190100           0.203209        0.137254             0.152762
# 44       0.190100           0.203209        0.137254             0.152762
#
#     sheep_nz_prop  sofa_nz_prop  train_nz_prop  tvmonitor_nz_prop  \
# 42       0.186018      0.230259       0.254034           0.180415
# 43       0.180393      0.255663       0.266767           0.141175
# 44       0.180393      0.255663       0.266767           0.141175
#
#     background_nz_prop  border_nz_prop
# 42            0.703712        0.048402
# 43            0.701878        0.049107
# 44            0.701878        0.049107
#
# [3 rows x 150 columns]

# %%
result_df.to_csv('./data/final_result.csv', index=False)
